# %% [markdown]
# # **2.1.1.6 LAB: The print() function**
# ## **Estimated time:**
# 5-10 minutes
#
# ## **Level of difficulty**:
# Very easy
#
# ## **Objectives:**
# - becoming familiar with the `print()` function and its formatting capabilities;
# - experimenting with Python code.
#
# ## **Scenario:**
# The `print()` command, which is one of the easiest directives in Python, simply prints out a line to the screen.
#
# In your first lab:

# %% [markdown]
# >use the `print()` function to print the line `Hello, Python!` to the screen. Use double quotes around the string;

# %%
print("Hello, Python!")
# Out:
# Hello, Python!

# %% [markdown]
# >having done that, use the `print()` function again, but this time print your first name;

# %%
print("Nico")
# Out:
# Nico

# %% [markdown]
# >remove the double quotes and run your code. Watch Python's reaction. What kind of error is thrown?

# %%
print(Hello, Python!)
# Out:
#   Cell In[3], line 1
#     print(Hello, Python!)
#                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# >then, remove the parentheses, put back the double quotes, and run your code again. What kind of error is thrown this time?

# %%
print "Hello, Python!"
# Out:
#   Cell In[4], line 1
#     print "Hello, Python!"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %% [markdown]
# >experiment as much as you can. Change double quotes to single quotes, use multiple `print()` functions on the same line, and then on different lines. See what happens.

# %%
print('Hello, Python!')
# Out:
# Hello, Python!

# %%
print("Hello, Python!") print("Nico")
# Out:
#   Cell In[6], line 1
#     print("Hello, Python!") print("Nico")
#                             ^
# SyntaxError: invalid syntax

# %%
print("Hello, Python!")
print("Nico")
# Out:
# Hello, Python!
# Nico

# %% [markdown]
# # **2.1.1.18 LAB: The print() function**
#
# ## **Estimated time:**
# 5-10 minutes
#
# ## **Level of difficulty:**
# Very Easy
#
# ## **Objectives:**
# becoming familiar with the `print()` function and its formatting capabilities;
# experimenting with Python code.
#
# ## **Scenario:**
# Modify the first line of code in the editor, using the `sep` and `end` keywords, to match the expected output. Use the two `print()` functions in the editor.
#
# Don't change anything in the second `print()` invocation.
#
# ## **Expected output:**
# >`Programming***Essentials***in...Python`

# %%
print("Programming","Essentials","in",sep="***",end="...")
print("Python")
# Out:
# Programming***Essentials***in...Python

# %% [markdown]
# # **2.1.1.19 LAB: Formatting the output**
#
# ## **Estimated time:**
# 5-15 minutes
#
# ## **Level of difficulty:**
# Easy
#
# ## **Objectives:**
# - experimenting with existing Python code;
# - discovering and fixing basic syntax errors;
# - becoming familiar with the print() function and its formatting capabilities.
#
# ## **Scenario:**
# We strongly encourage you to **play with the code** we've written for you, and make some (maybe even destructive) amendments. Feel free to modify any part of the code, but there is one condition - learn from your mistakes and draw your own conclusions.
#
# Try to:

# %% [markdown]
# >minimize the number of `print()` function invocations by inserting the `\n` sequence into the strings

# %%
# From this
print("    *")
print("   * *")
print("  *   *")
print(" *     *")
print("***   ***")
print("  *   *")
print("  *   *")
print("  *****")

# To this
print("    *\n   * *\n  *   *\n *     *\n***   ***\n  *   *\n  *   *\n  *****")
# Out:
#     *
#    * *
#   *   *
#  *     *
# ***   ***
#   *   *
#   *   *
#   *****
#     *
#    * *
#   *   *
#  *     *
# ***   ***
#   *   *
#   *   *
#   *****

# %% [markdown]
# >make the arrow twice as large (but keep the proportions)

# %%
# From this
print("    *")
print("   * *")
print("  *   *")
print(" *     *")
print("***   ***")
print("  *   *")
print("  *   *")
print("  *****")

# To this
print("        **")
print("      **  **")
print("    **      **")
print("  **          **")
print("******      ******")
print("    **      **")
print("    **      **")
print("    **********")

# Or this
print("        **")
print("        **")
print("      **  **")
print("      **  **")
print("    **      **")
print("    **      **")
print("  **          **")
print("  **          **")
print("******      ******")
print("******      ******")
print("    **      **")
print("    **      **")
print("    **      **")
print("    **      **")
print("    **********")
print("    **********")
# Out:
#     *
#    * *
#   *   *
#  *     *
# ***   ***
#   *   *
#   *   *
#   *****
#         **
#       **  **
#     **      **
#   **          **
# ******      ******
#     **      **
#     **      **
#     **********
#         **
#         **
#       **  **
#       **  **
#     **      **
#     **      **
#   **          **
#   **          **
# ******      ******
# ******      ******
#     **      **
#     **      **
#     **      **
#     **      **
#     **********
#     **********

# %% [markdown]
# >duplicate the arrow, placing both arrows side by side; note: a string may be multiplied by using the following trick: `"string" * 2` will produce `"stringstring"` (we'll tell you more about it soon)

# %%
# From this
print("    *")
print("   * *")
print("  *   *")
print(" *     *")
print("***   ***")
print("  *   *")
print("  *   *")
print("  *****")

# To this
print("    *    "*2)
print("   * *   "*2)
print("  *   *  "*2)
print(" *     * "*2)
print("***   ***"*2)
print("  *   *  "*2)
print("  *   *  "*2)
print("  *****  "*2)
# Out:
#     *
#    * *
#   *   *
#  *     *
# ***   ***
#   *   *
#   *   *
#   *****
#     *        *
#    * *      * *
#   *   *    *   *
#  *     *  *     *
# ***   ******   ***
#   *   *    *   *
#   *   *    *   *
#   *****    *****

# %% [markdown]
# >remove any of the quotes, and look carefully at Python's response; pay attention to where Python sees an error - is this the place where the error really exists?

# %%
# From this
print("    *")
print("   * *")
print("  *   *")
print(" *     *")
print("***   ***")
print("  *   *")
print("  *   *")
print("  *****")

# To this
print("    *")
print("   * *")
print("  *   *")
print(" *     *")
print("***   ***)
print("  *   *")
print("  *   *")
print("  *****")
# Out:
#   Cell In[12], line 16
#     print("***   ***)
#           ^
# SyntaxError: unterminated string literal (detected at line 16)

# %% [markdown]
# >do the same with some of the parentheses;

# %%
# From this
print("    *")
print("   * *")
print("  *   *")
print(" *     *")
print("***   ***")
print("  *   *")
print("  *   *")
print("  *****")

# To this
print("    *")
print("   * *")
print("  *   *")
print(" *     *")
print("***   ***"
print("  *   *")
print("  *   *")
print("  *****")
# Out:
#   Cell In[13], line 16
#     print("***   ***"
#          ^
# SyntaxError: '(' was never closed

# %% [markdown]
# >change any of the `print` words into something else, differing only in case (e.g., `Print`) - what happens now?

# %%
# From this
print("    *")
print("   * *")
print("  *   *")
print(" *     *")
print("***   ***")
print("  *   *")
print("  *   *")
print("  *****")

# To this
print("    *")
print("   * *")
print("  *   *")
print(" *     *")
Print("***   ***")
print("  *   *")
print("  *   *")
print("  *****")
# Out:
#     *
#    * *
#   *   *
#  *     *
# ***   ***
#   *   *
#   *   *
#   *****
#     *
#    * *
#   *   *
#  *     *
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 16
#      14 print("  *   *")
#      15 print(" *     *")
# ---> 16 Print("***   ***")
#      17 print("  *   *")
#      18 print("  *   *")
#
# NameError: name 'Print' is not defined

# %% [markdown]
# >replace some of the quotes with apostrophes; watch what happens carefully.

# %%
# From this
print("    *")
print("   * *")
print("  *   *")
print(" *     *")
print("***   ***")
print("  *   *")
print("  *   *")
print("  *****")

# To this
print("    *")
print("   * *")
print("  *   *")
print(" *     *")
print("***   ***``)
print("  *   *")
print("  *   *")
print("  *****")
# Out:
#   Cell In[15], line 16
#     print("***   ***``)
#           ^
# SyntaxError: unterminated string literal (detected at line 16)

# %% [markdown]
# # **2.2.1.11 LAB: Python literals - strings**
#
# ## **Estimated time:**
# 5-10 minutes
#
# ## **Level of difficulty:**
# Easy
#
# ## **Objectives:**
# - becoming familiar with the `print()` function and its formatting capabilities;
# - practicing coding strings;
# - experimenting with Python code.
#
# ## **Scenario:**
# Write a one-line piece of code, using the `print()` function, as well as the newline and escape characters, to match the expected result outputted on three lines.
#
# ## **Expected output:**
# >`"I'm"`
# `""learning""`
# `"""Python"""`

# %%
print('"I\'m"', '""learning""', '"""Python"""', sep="\n")
# Out:
# "I'm"
# ""learning""
# """Python"""

# %% [markdown]
# # **2.4.1.7 LAB: Variables**
#
# ## **Estimated time:**
# 10 minutes
#
# ## **Level of difficulty:**
# Easy
#
# ## **Objectives:**
# becoming familiar with the concept of storing and working with different data types in Python;
# experimenting with Python code.
# Scenario
# Here is a short story:
#
# >Once upon a time in Appleland, John had three apples, Mary had five apples, and Adam had six apples. They were all very happy and lived for a long time. End of story.
#
# Your task is to:

# %% [markdown]
# >- create the variables: `john`, `mary`, and `adam`;
# >- assign values to the variables. The values must be equal to the numbers of fruit possessed by John, Mary, and Adam respectively;

# %%
john = 3
mary = 5
adam = 6

# %% [markdown]
# >- having stored the numbers in the variables, print the variables on one line, and separate each of them with a comma;

# %%
print(john, mary, adam, sep=", ")
# Out:
# 3, 5, 6

# %% [markdown]
# >- now create a new variable named `total_apples` equal to addition of the three former variables.

# %%
total_apples = john + mary + adam

# %% [markdown]
# >- print the value stored in `total_apples` to the console;

# %%
print(total_apples)
# Out:
# 14

# %% [markdown]
# >- **experiment with your code**: create new variables, assign different values to them, and perform various arithmetic operations on them (e.g., +, -, *, /, //, etc.). Try to print a string and an integer together on one line, e.g., `"Total number of apples:"` and `total_apples`.

# %%
george = 1
abraham = 16
franklin = 32

total_apples = george * 8 + abraham // 4 + franklin ** 2

print("Total number of apples:", total_apples)
# Out:
# Total number of apples: 1036

# %% [markdown]
# # **2.4.1.9 LAB: Variables: a simple converter**
#
# ## **Estimated time:**
# 10 minutes
#
# ## **Level of difficulty:**
# Easy
#
# ## **Objectives:**
# - becoming familiar with the concept of, and working with, variables;
# - performing basic computations and conversions;
# - experimenting with Python code.
#
# ## **Scenario:**
# Miles and kilometers are units of length or distance.
#
# Bearing in mind that `1` mile is equal to approximately `1.61` kilometers, complete the program in the editor so that it converts:
# - miles to kilometers;
# - kilometers to miles.
#
# Do not change anything in the existing code. Write your code in the places indicated by `###`. Test your program with the data we've provided in the source code.
#
#
# Pay particular attention to what is going on inside the `print()` function. Analyze how we provide multiple arguments to the function, and how we output the expected data.
#
# Note that some of the arguments inside the `print()` function are strings (e.g., `"miles is"`, whereas some other are variables (e.g., `miles`).
#
# ## **Expected output:**
# >`7.38 miles is 11.88 kilometers`
# `12.25 kilometers is 7.61 miles`

# %%
kilometers = 12.25
miles = 7.38

miles_to_kilometers = miles * 1.60934
kilometers_to_miles = kilometers * 0.621371

print(miles, "miles is", round(miles_to_kilometers, 2), "kilometers")
print(kilometers, "kilometers is", round(kilometers_to_miles, 2), "miles")
# Out:
# 7.38 miles is 11.88 kilometers
# 12.25 kilometers is 7.61 miles

# %% [markdown]
# >After completing the lab, open Sandbox, and experiment more. Try to write different converters, e.g., a USD to EUR converter, a temperature converter, etc. - let your imagination fly! Try to output the results by combining strings and variables. Try to use and experiment with the `round()` function to round your results to one, two, or three decimal places. Check out what happens if you don't provide any number of digits. Remember to test your programs.
#
# >Experiment, draw conclusions, and learn. Be curious.

# %%
#  Currency converter
usd = 349.99
eur = 499.99

usd_to_eur = usd * 0.85     #  currency rate on 23 July 2021
eur_to_usd = eur * 1.18     #  currency rate on 23 July 2021

print("\nCurrency converter")
print("US$", usd, "is equal to €", round(usd_to_eur, 2))
print("€", eur, "is equal to US$", round(eur_to_usd, 2))

#  Temperature converter
celsius = 31
fahrenheit = 67

celsius_to_fahrenheit = (celsius * 9/5) + 32
fahrenheit_to_celsius = (fahrenheit - 32) * 5/9

print("\nTemperature converter")
print(celsius, "°C is equal to", round(celsius_to_fahrenheit), "°F")
print(fahrenheit, "°F is equal to", round(fahrenheit_to_celsius), "°C")

#  Weight converter
kg = 72.5
lbs = 159.8

kg_to_lbs = kg * 2.20462
lbs_to_kg = lbs * 0.453592

print("\nWeight converter")
print(kg, "kilogram equals to", round(kg_to_lbs, 1), "lbs")
print(lbs, "lbs equals to", round(lbs_to_kg, 1), "kilogram")
# Out:
# Currency converter
# US$ 349.99 is equal to € 297.49
# € 499.99 is equal to US$ 589.99
#
# Temperature converter
# 31 °C is equal to 88 °F
# 67 °F is equal to 19 °C
#
# Weight converter
# 72.5 kilogram equals to 159.8 lbs
# 159.8 lbs equals to 72.5 kilogram

# %% [markdown]
# # **2.4.1.10 LAB: Operators and expressions**
#
# ## **Estimated time:**
# 10-15 minutes
#
# ## **Level of difficulty:**
# Easy
#
# ## **Objectives:**
# - becoming familiar with the concept of numbers, operators, and arithmetic operations in Python;
# - performing basic calculations.
#
# ## **Scenario:**
# Take a look at the code in the editor: it reads a `float` value, puts it into a variable named `x`, and prints the value of a variable named `y`. Your task is to complete the code in order to evaluate the following expression:
#
# >3x<sup>3</sup> - 2x<sup>2</sup> + 3x - 1
#
# The result should be assigned to `y`.
#
# Remember that classical algebraic notation likes to omit the multiplication operator - you need to use it explicitly. Note how we change data type to make sure that `x` is of type `float`.
#
# Keep your code clean and readable, and test it using the data we've provided, each time assigning it to the `x` variable (by hardcoding it). Don't be discouraged by any initial failures. Be persistent and inquisitive.
#
#
# ## **Test Data**
# **Sample input:**
# >`x = 0`
# `x = 1`
# `x = -1`
#
# **Expected Output:**
# >`y = -1.0`
# `y = 3.0`
# `y = -9.0`

# %%
x = 0
x = float(x)
y = 3 * x ** 3 - 2 * x ** 2 + 3 * x - 1
print("y =", y)

x = 1
x = float(x)
y = 3 * x ** 3 - 2 * x ** 2 + 3 * x - 1
print("y =", y)

x = -1
x = float(x)
y = 3 * x ** 3 - 2 * x ** 2 + 3 * x - 1
print("y =", y)
# Out:
# y = -1.0
# y = 3.0
# y = -9.0

# %% [markdown]
# # **2.5.1.2 LAB: Comments**
#
# ## **Estimated time:**
# 5 minutes
#
# ## **Level of difficulty:**
# Very Easy
#
# ## **Objectives:**
# - becoming familiar with the concept of comments in Python;
# - using and not using comments;
# - replacing comments with code;
# - experimenting with Python code.
#
# ## **Scenario:**
# The code in the editor contains comments. Try to improve it: add or remove comments where you find it appropriate (yes, sometimes removing a comment can make the code more readable), and change variable names where you think this will improve code comprehension.

# %%
#  this program computes the number of seconds in a given number of hours
#  this program has been written two days ago

a = 2           #  number of hours
seconds = 3600  #  number of seconds in 1 hour

print("Hours: ", a)                         #  printing the number of hours
print("Seconds in Hours: ", a * seconds)    #  printing the number of seconds in a given number of hours
# Out:
# Hours:  2
# Seconds in Hours:  7200

# %% [markdown]
# # **2.6.1.9 LAB: Simple input and output**
#
# ## **Estimated time:**
# 5-10 minutes
#
# ## **Level of difficulty:**
# Easy
#
# ## **Objectives:**
# - becoming familiar with the inputting and outputting of data in Python;
# - evaluating simple expressions.
#
# ## **Scenario:**
# Your task is to complete the code in order to evaluate the results of four basic arithmetic operations.
#
# The results have to be printed to the console.
#
# You may not be able to protect the code from a user who wants to divide by zero. That's okay, don't worry about it for now.
#
# Test your code - does it produce the results you expect?
#
# We won't show you any test data - that would be too simple.

# %%
a = float(input("Input a number: "))  #  input a float value for variable a here
b = float(input("Input a number: "))  #  input a float value for variable b here

print(a, "+", b, "=", a + b)        #  output the result of addition here
print(a, "-", b, "=", a - b)        #  output the result of subtraction here
print(a, "*", b, "=", a * b)        #  output the result of multiplication here
print(a, "/", b, "=", a / b)        #  output the result of division here

print("\nThat's all, folks!")
# Out:
# 1.0 + 2.0 = 3.0
# 1.0 - 2.0 = -1.0
# 1.0 * 2.0 = 2.0
# 1.0 / 2.0 = 0.5
#
# That's all, folks!

# %% [markdown]
# # **2.6.1.10 LAB: Operators and expressions**
#
# ## **Estimated time:**
# 20 minutes
#
# ## **Level of difficulty**
# Intermediate
#
# ## **Objectives:**
# - becoming familiar with the concept of numbers, operators and arithmetic operations in Python;
# - understanding the precedence and associativity of Python operators, as well as the proper use of parentheses.
#
# ## **Scenario:**
# Your task is to complete the code in order to evaluate the following expression:
#
# ![picture](https://drive.google.com/uc?export=view&id=1p_qrC66AbeQaui9zFMNaY9hR4cKHfOoW)
#
# The result should be assigned to `y`. Be careful - watch the operators and keep their priorities in mind. Don't hesitate to use as many parentheses as you need.
#
# You can use additional variables to shorten the expression (but it's not necessary). Test your code carefully.
#
#
# ## **Test Data**
# >**Sample input:**
# `1`
#
# >**Expected output:**
# `y = 0.6000000000000001`
#
# >**Sample input:**
# `10`
#
# >**Expected output:**
# `y = 0.09901951266867294`
#
# >**Sample input:**
# `100`
#
# >**Expected output:**
# `y = 0.009999000199950014`
#
# >**Sample input:**
# `-5`
#
# >**Expected output:**
# `y = -0.19258202567760344`

# %%
x = float(input("Enter value for x: "))

#  Write your code here.
y = 1 / (x + (1 / (x + (1 / (x + (1 / x))))))

print("y =", y)
# Out:
# y = 0.6000000000000001

# %% [markdown]
# # **2.6.1.11 LAB: Operators and expressions**
#
# ## **Estimated time:**
# 15-20 minutes
#
# ## **Level of difficulty:**
# Easy
#
# ## **Objectives:**
# - improving the ability to use numbers, operators, and arithmetic operations in Python;
# - using the `print()` function's formatting capabilities;
# - learning to express everyday-life phenomena in terms of programming language.
#
# ## **Scenario:**
# Your task is to prepare a simple code able to evaluate the **end time** of a period of time, given as a number of minutes (it could be arbitrarily large). The start time is given as a pair of hours (0..23) and minutes (0..59). The result has to be printed to the console.
#
# For example, if an event starts at **12:17** and lasts **59 minutes**, it will end at **13:16**.
#
# Don't worry about any imperfections in your code - it's okay if it accepts an invalid time - the most important thing is that the code produce valid results for valid input data.
#
# Test your code carefully. Hint: using the `%` operator may be the key to success.
#
# ## **Test Data**
# >**Sample input:**
# `12`
# `17`
# `59`
#
# >**Expected output:**
# `13:16`
#
# >**Sample input:**
# `23`
# `58`
# `642`
#
# >**Expected output:**
# `10:40`
#
#
# >**Sample input:**
# `1`
# `2939`
#
# >**Expected output:**
# `1:0`

# %%
hour = int(input("Starting time (hours): "))
mins = int(input("Starting time (minutes): "))
dura = int(input("Event duration (minutes): "))

#  Write your code here.
time_in_second = (hour * 3600) + (mins * 60)                #  convert time to second
duration_in_second = dura * 60                              #  convert duration to second
total_time_in_second = time_in_second + duration_in_second  #  sum total time in second

#  get hours end by converting sum total time in second to hour
end_hour = (total_time_in_second // 3600) % 24
#  get minutes end by converting sum total time in second to minute
end_minute = (total_time_in_second % 3600) // 60

#  print end time in desired format
print(str(end_hour) + ":" + str(end_minute))
# Out:
# 13:16
